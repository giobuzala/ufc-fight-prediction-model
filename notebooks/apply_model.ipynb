# %% [markdown]
# # UFC Fight Prediction Model Application

# %%
# Core
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Local
import sys
from pathlib import Path
SRC_PATH = Path("..") / "src"
sys.path.append(str(SRC_PATH.resolve()))
from predict import predict_fight

# %% [markdown]
# ## Data Loading

# %%
data = pd.read_csv("../data/ufc_upcoming_fights.csv")

# %% [markdown]
# ## Data Exploration

# %%
data.head(5)
# Out:
#         RedFighter        BlueFighter  RedOdds  BlueOdds  RedExpectedValue  \
# 0  Colby Covington    Joaquin Buckley      205      -250          205.0000
# 1      Cub Swanson  Billy Quarantillo      124      -148          124.0000
# 2       Manel Kape        Bruno Silva     -395       310           25.3165
# 3    Vitor Petrino      Dustin Jacoby     -340       270           29.4118
# 4     Adrian Yanez      Daniel Marcos      185      -225          185.0000
#
#    BlueExpectedValue        Date             Location Country  Winner  ...  \
# 0            40.0000  2024-12-14  Tampa, Florida, USA     USA     NaN  ...
# 1            67.5676  2024-12-14  Tampa, Florida, USA     USA     NaN  ...
# 2           310.0000  2024-12-14  Tampa, Florida, USA     USA     NaN  ...
# 3           270.0000  2024-12-14  Tampa, Florida, USA     USA     NaN  ...
# 4            44.4444  2024-12-14  Tampa, Florida, USA     USA     NaN  ...
#
# ...

# %%
data.shape
# Out:
# (13, 118)

# %% [markdown]
# ## Predict Fights

# %%
data = predict_fight(data)

data["PredictedWinnerName"] = np.where(
    data["PredictedWinner"] == "Red",
    data["RedFighter"],
    data["BlueFighter"]
)

# %%
data[["RedFighter", "BlueFighter", "RedOdds", "BlueOdds", "RedPredOdds", "BluePredOdds", "PredictedWinnerName"]]
# Out:
#            RedFighter        BlueFighter  RedOdds  BlueOdds  RedPredOdds  \
# 0     Colby Covington    Joaquin Buckley      205      -250     0.540506
# 1         Cub Swanson  Billy Quarantillo      124      -148     0.358051
# 2          Manel Kape        Bruno Silva     -395       310     0.411038
# 3       Vitor Petrino      Dustin Jacoby     -340       270     0.627804
# 4        Adrian Yanez      Daniel Marcos      185      -225     0.513738
# 5     Navajo Stirling        Tuco Tokkos     -750       525     0.186665
# 6     Michael Johnson     Ottman Azaitar     -230       190     0.485653
# 7        Joel Alvarez      Drakkar Klose     -425       330     0.512552
# 8        Sean Woodson   Fernando Padilla     -155       130     0.859003
# 9         Miles Johns        Felipe Lima      210      -258     0.497683
# 10   Miranda Maverick    Jamey-Lyn Horth     -625       455     0.559689
# 11        Davey Grant      Ramon Taveras     -122       102     0.642483
# ...
